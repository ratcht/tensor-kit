# %%
# import os
# from huggingface_hub import hf_hub_download
# import safetensors

# # Define model and safetensor file names (assuming you have these names)
# model_id = "your-model-id"
# filenames = ["file1.safetensors", "file2.safetensors", "file3.safetensors"]

# # Function to load safetensor tensors
# def load_safetensor_tensors(model_id, filenames):
#   tensors = []
#   for filename in filenames:
#     # Download safetensor file from the HF hub
#     local_filepath = hf_hub_download(repo_id=model_id, filename=filename)
    
#     # Use safe_open for memory efficient reading
#     with safetensors.safe_open(local_filepath, framework="pt") as f:
#       for key in f.keys():
#         tensors.append((key, f[key]))  # Storing as (key, tensor) tuples
#   return tensors

# # Load tensors lazily
# def iterate_tensors(tensors):
#   for key, tensor in tensors:
#     yield key, tensor

# # Example usage
# tensors = load_safetensor_tensors(model_id, filenames)
# for key, tensor in iterate_tensors(tensors):
#   print(f"Key: {key}, Tensor: {tensor}")

# %%
import json
import torch
import transformers
import safetensors
import os
from huggingface_hub import hf_hub_download
from typing import Generator

class ModelTree:
  def __init__(self, weight_map: dict):
    self.keys: list[str] = list(weight_map.keys())
    self.file_names = set(weight_map.values())
    self.flattened_tree = weight_map

    self.tree = {}

    for key in self.keys:
      split_key = key.split(".")
      tree = self.tree
      for i, part in enumerate(split_key):
        if i < len(split_key) - 1:
          tree = tree.setdefault(part, {})
        else:
          tree = tree.setdefault(split_key[i], self.flattened_tree[key])

import typing
from abc import ABC, abstractmethod

class TensorLoader(ABC):
  """Naive `torch.load` shard loading."""

  tensors: dict[str, torch.Tensor]
  shard_path: str

  @classmethod
  def get_loader(self, shard_path: str, device: typing.Optional[str] = None):
    if shard_path.endswith(".safetensors"):
      return SafetensorLoader(shard_path, device=device)
    elif shard_path.endswith(".bin"):
      return PytorchLoader(shard_path, device=device)

  @abstractmethod
  def get_tensor(self, key: str) -> torch.Tensor:
      ...

  @abstractmethod
  def keys(self) -> list[str]:
      ...

class PytorchLoader(TensorLoader):
  def __init__(self, path: str, device: typing.Optional[str] = None):
    self.tensors = torch.load(path, map_location=device, weights_only=True)
    self.shard_path = path

  def get_tensor(self, key: str) -> torch.Tensor:
    return self.tensors[key]

  def keys(self) -> list[str]:
    return list(self.tensors.keys())

class SafetensorLoader(TensorLoader):
  def __init__(self, path: str, device: typing.Optional[str] = None):
    self.tensors = {}
    with safetensors.safe_open(path, framework="pt") as f:
      for k in f.keys():
        self.tensors[k] = f.get_tensor(k)
    self.shard_path = path

  def get_tensor(self, key: str) -> torch.Tensor:
    return self.tensors[key]

  def keys(self) -> list[str]:
    return list(self.tensors.keys())


class ModelLoader:
  def __init__(self, model_name, is_cached=True, device="cpu"):
    if not is_cached: raise Exception("Model must be downloaded first. Auto-download not implemented yet.")

    self.device = device
    self.config_path = transformers.utils.hub.cached_file(model_name, "config.json")
    self.model_dir: list[str] = os.path.dirname(self.config_path)


    self.index_path = [f for f in os.listdir(self.model_dir) if f.endswith(".index.json")]
    assert(len(self.index_path) == 1)

    self.index_path = self.index_path[0]

    with open(os.path.join(self.model_dir, self.index_path)) as f:
      self.index_dict: dict[str, dict[str, str]] = json.load(f)
      self.weight_map: dict[str, str] = self.index_dict["weight_map"]

      self.model_tree = ModelTree(self.weight_map)

    self.cached_loader = (None,None)
  
  def get_tensor_loader(self, key) -> TensorLoader:
    parent_file = self.weight_map[key]
  
    if parent_file == self.cached_loader[0]: return self.cached_loader[1]

    del self.cached_loader
    
    tensor_loader = TensorLoader.get_loader(os.path.join(self.model_dir, parent_file))
    self.cached_loader = (parent_file, tensor_loader)
    return tensor_loader

  def iterate_tensors(self, ordered=True) -> Generator:
    tensor_keys = list(self.weight_map.keys())
    for key in tensor_keys:
      tensor_loader = self.get_tensor_loader(key)
      yield (key,tensor_loader.get_tensor(key))

  def flush(self):
    del self.cached_loader
    self.cached_loader = (None, None)

  def print_tree(self):
    print(self.model_tree.tree)

# %%
# model_loader_test = ModelLoader("argilla/CapybaraHermes-2.5-Mistral-7B")

model_loader_test = ModelLoader("Open-Orca/Mistral-7B-OpenOrca")

# %%
for tensor in model_loader_test.iterate_tensors():
  print(tensor)
# Out:
# ('lm_head.weight', tensor([[-2.5787e-03,  8.9645e-04, -2.3499e-03,  ..., -2.6894e-04,
#           4.0894e-03,  1.8616e-03],
#         [-2.5482e-03,  1.4343e-03, -2.3956e-03,  ...,  5.4169e-04,
#           5.9509e-03,  2.0294e-03],
#         [ 2.7466e-03,  3.3722e-03,  2.4109e-03,  ..., -3.6163e-03,
#          -2.9144e-03,  2.1820e-03],
#         ...,
#         [ 2.7313e-03, -4.3335e-03,  3.5858e-03,  ..., -6.5918e-03,
#           1.9073e-03, -7.7724e-05],
#         [ 1.4709e-02, -1.6327e-03, -1.5717e-03,  ..., -4.8828e-03,
#          -2.1362e-02,  2.0996e-02],
#         [ 2.5635e-03, -4.7302e-03, -5.6152e-03,  ...,  1.6235e-02,
#          -3.3188e-04, -3.2715e-02]], dtype=torch.bfloat16))
# ('model.embed_tokens.weight', tensor([[-1.7643e-05, -2.5511e-05, -1.4126e-05,  ...,  2.8253e-05,
#          -8.3447e-06,  1.8477e-05],
#         [-4.5776e-03,  3.2616e-04, -5.1270e-03,  ..., -1.8978e-04,
#          -1.1902e-03,  3.0708e-04],
#         [-1.5640e-03,  9.3079e-04,  1.8692e-04,  ...,  1.1749e-03,
#           3.3760e-04,  3.3379e-05],
#         ...,
#         [-3.9673e-03, -9.7656e-04, -5.3711e-03,  ...,  4.1809e-03,
#           5.1975e-05, -2.5024e-03],
#         [ 2.0264e-02, -4.8828e-03, -2.5024e-02,  ...,  1.8677e-02,
#           2.7100e-02, -2.0020e-02],
#         [ 6.2180e-04,  1.0925e-02, -1.2085e-02,  ...,  2.8839e-03,
#           1.9989e-03, -3.3722e-03]], dtype=torch.bfloat16))
# ('model.layers.0.input_layernorm.weight', tensor([ 6.2466e-05, -1.2146e-02,  1.2875e-04,  ...,  3.5400e-02,
#         -2.4128e-04,  6.4697e-03], dtype=torch.bfloat16))
# ('model.layers.0.mlp.down_proj.weight', tensor([[-0.0028,  0.0004, -0.0006,  ..., -0.0017,  0.0037, -0.0007],
#         [ 0.0013, -0.0049,  0.0024,  ..., -0.0017,  0.0015, -0.0038],
#         [ 0.0055, -0.0082,  0.0022,  ...,  0.0030, -0.0051,  0.0042],
#         ...,
#         [ 0.0055,  0.0023, -0.0014,  ..., -0.0011,  0.0055, -0.0014],
#         [-0.0025,  0.0025, -0.0018,  ...,  0.0008,  0.0001,  0.0017],
#         [-0.0027, -0.0054, -0.0007,  ..., -0.0045,  0.0008, -0.0020]],
#        dtype=torch.bfloat16))
# ('model.layers.0.mlp.gate_proj.weight', tensor([[-4.3030e-03, -1.0986e-03, -1.3657e-03,  ...,  2.6398e-03,
#           3.5095e-03,  3.1128e-03],
#         [ 3.5248e-03, -5.4932e-04,  6.0654e-04,  ...,  3.8528e-04,
#           3.2196e-03,  1.1520e-03],
#         [-6.7520e-04,  1.5869e-03,  1.5335e-03,  ..., -3.0212e-03,
#          -1.7929e-03, -1.2817e-03],
#         ...,
#         [ 2.0294e-03, -6.2561e-04, -2.2583e-03,  ...,  2.5558e-04,
#          -3.1281e-03,  9.1934e-04],
#         [ 2.4414e-03, -4.2725e-03, -4.5586e-04,  ..., -1.5378e-05,
#           3.3379e-04,  4.2725e-03],
#         [ 2.9144e-03,  7.5531e-04,  4.4556e-03,  ...,  1.5488e-03,
#          -2.1362e-03, -3.7079e-03]], dtype=torch.bfloat16))
# ('model.layers.0.mlp.up_proj.weight', tensor([[-2.1648e-04, -1.3065e-04, -8.4305e-04,  ...,  5.5847e-03,
#           3.6469e-03,  3.9482e-04],
#         [-4.1504e-03, -1.1139e-03, -1.6785e-03,  ...,  2.1057e-03,
#           1.9531e-03, -1.6212e-04],
#         [-3.3569e-04,  1.7395e-03, -1.5869e-03,  ...,  1.4648e-03,
#          -6.5613e-04, -5.3024e-04],
#         ...,
#         [-2.8992e-03, -1.5182e-03,  1.6327e-03,  ..., -3.6163e-03,
#          -2.7771e-03,  4.3030e-03],
#         [ 2.6703e-03, -2.7313e-03, -5.8594e-03,  ...,  3.1853e-04,
#          -6.6223e-03,  3.9062e-03],
#         [-1.5335e-03, -1.6861e-03,  2.2316e-04,  ...,  1.4267e-03,
#          -5.4932e-03,  9.4175e-06]], dtype=torch.bfloat16))
# ('model.layers.0.post_attention_layernorm.weight', tensor([0.4160, 0.4121, 0.3945,  ..., 0.4199, 0.3965, 0.4004],
#        dtype=torch.bfloat16))
# ('model.layers.0.self_attn.k_proj.weight', tensor([[-1.5646e-06, -3.3417e-03,  1.2589e-04,  ..., -1.6357e-02,
#           1.8120e-04, -8.7738e-04],
#         [ 1.6093e-05,  1.9226e-03, -8.0585e-05,  ...,  7.0190e-03,
#          -9.0122e-05,  8.4686e-04],
#         [-2.0623e-05,  3.0518e-03, -6.4373e-05,  ...,  1.7944e-02,
#          -1.0586e-04,  6.1035e-04],
#         ...,
#         [-2.4605e-04,  1.9150e-03, -4.1962e-04,  ...,  2.1362e-03,
#           3.6812e-04, -2.4796e-04],
#         [-1.6975e-04, -4.3640e-03, -2.5940e-04,  ...,  5.9128e-04,
#           5.4169e-04, -2.2736e-03],
#         [ 2.4796e-04, -1.7700e-03,  4.4632e-04,  ..., -1.8768e-03,
#          -4.0245e-04,  8.6594e-04]], dtype=torch.bfloat16))
# ('model.layers.0.self_attn.o_proj.weight', tensor([[ 5.9509e-04,  4.5166e-03,  4.2725e-03,  ..., -1.0071e-03,
#          -1.9360e-04,  1.4782e-04],
#         [ 2.2793e-04, -2.6093e-03, -6.5231e-04,  ...,  8.5831e-04,
#          -1.3046e-03, -9.6512e-04],
#         [-2.0294e-03,  2.0294e-03,  4.7445e-05,  ...,  1.2665e-03,
#           3.4027e-03, -3.0212e-03],
#         ...,
#         [ 3.9368e-03, -1.3504e-03,  2.0447e-03,  ..., -3.3112e-03,
#           1.3733e-03,  5.3101e-03],
#         [ 2.8687e-03, -3.8147e-03, -2.1973e-03,  ..., -3.3951e-04,
#          -2.8076e-03, -3.9864e-04],
#         [ 4.4861e-03, -2.9907e-03, -2.2736e-03,  ...,  4.1962e-04,
#           1.6785e-03, -4.6349e-04]], dtype=torch.bfloat16))
# ('model.layers.0.self_attn.q_proj.weight', tensor([[ 5.3883e-05,  1.2436e-03, -3.0160e-05,  ...,  4.3945e-03,
#           2.8491e-05, -6.1417e-04],
#         [-4.6730e-05, -3.7193e-04,  2.3246e-05,  ..., -2.7466e-04,
#           5.6028e-06,  3.1281e-04],
#         [ 1.8120e-05, -5.1498e-04,  7.2420e-06,  ..., -6.0730e-03,
#          -2.5392e-05, -4.1199e-04],
#         ...,
#         [-2.1935e-05, -1.7166e-03, -2.7537e-05,  ...,  4.3869e-04,
#           1.1861e-05,  3.5095e-04],
#         [ 7.4506e-06, -1.5564e-03,  1.1623e-05,  ..., -2.0599e-03,
#          -2.9802e-05,  7.6675e-04],
#         [ 2.2769e-05,  1.9836e-03,  2.4915e-05,  ..., -2.4033e-04,
#          -1.1504e-05, -4.9210e-04]], dtype=torch.bfloat16))
# ('model.layers.0.self_attn.v_proj.weight', tensor([[-4.1962e-04, -1.7090e-03, -6.5231e-04,  ...,  4.9744e-03,
#          -9.5963e-06,  2.1057e-03],
#         [-5.1117e-04,  5.0354e-03, -3.8147e-04,  ...,  4.4556e-03,
#          -7.4005e-04, -6.8665e-04],
#         [ 2.7275e-04,  2.0599e-03, -5.9891e-04,  ..., -6.3324e-04,
#          -1.0347e-04, -5.5542e-03],
#         ...,
#         [ 6.1417e-04,  2.1362e-03, -2.9755e-04,  ...,  3.4790e-03,
#          -1.7776e-03, -2.2888e-03],
#         [-3.5477e-04, -4.7302e-03, -4.2534e-04,  ...,  2.7618e-03,
#           7.0572e-04, -5.1880e-04],
#         [-6.2561e-04, -2.7466e-03,  5.1498e-04,  ..., -3.1471e-04,
#           6.1417e-04,  1.4038e-03]], dtype=torch.bfloat16))
# ('model.layers.1.input_layernorm.weight', tensor([1.6504e-01, 1.0596e-01, 1.5497e-05,  ..., 1.7188e-01, 1.0449e-01,
#         6.8359e-02], dtype=torch.bfloat16))
# ('model.layers.1.mlp.down_proj.weight', tensor([[-0.0012, -0.0041, -0.0004,  ...,  0.0012,  0.0088, -0.0011],
#         [-0.0022,  0.0024, -0.0011,  ...,  0.0053, -0.0053,  0.0007],
#         [ 0.0047, -0.0026,  0.0004,  ...,  0.0057,  0.0035,  0.0074],
#         ...,
#         [-0.0024,  0.0021,  0.0025,  ..., -0.0062, -0.0010,  0.0019],
#         [-0.0008, -0.0024, -0.0055,  ..., -0.0016, -0.0003, -0.0018],
#         [-0.0029, -0.0018, -0.0043,  ..., -0.0003,  0.0027,  0.0040]],
#        dtype=torch.bfloat16))
# ('model.layers.1.mlp.gate_proj.weight', tensor([[-4.5471e-03,  6.2256e-03,  1.9531e-03,  ..., -6.0425e-03,
#          -3.5706e-03,  1.4572e-03],
#         [-3.7231e-03,  1.2398e-04,  4.7607e-03,  ...,  2.2736e-03,
#          -1.9684e-03, -5.7373e-03],
#         [ 5.6152e-03, -3.3112e-03,  1.7853e-03,  ...,  5.1498e-04,
#           5.8289e-03,  1.2436e-03],
#         ...,
#         [ 8.2397e-04,  6.1035e-03, -4.5471e-03,  ...,  8.2397e-04,
#           1.9455e-03,  6.0272e-04],
#         [ 1.6098e-03, -1.9684e-03, -8.6975e-04,  ...,  4.1723e-05,
#           9.9182e-04, -3.4027e-03],
#         [ 1.9302e-03, -2.0313e-04, -1.5488e-03,  ..., -1.3962e-03,
#          -2.2602e-04, -2.2430e-03]], dtype=torch.bfloat16))
# ('model.layers.1.mlp.up_proj.weight', tensor([[-6.6833e-03,  5.4016e-03,  1.5411e-03,  ..., -9.9945e-04,
#           2.2125e-03, -1.6708e-03],
#         [ 2.1973e-03,  4.3869e-04,  6.4697e-03,  ...,  1.7471e-03,
#           9.4604e-03,  6.4850e-04],
#         [ 5.2214e-05,  9.6893e-04,  1.4114e-03,  ..., -2.7618e-03,
#          -2.4567e-03,  6.1646e-03],
#         ...,
#         [ 1.4267e-03,  1.8005e-03,  2.5635e-03,  ..., -2.4719e-03,
#          -6.4087e-04, -1.4954e-03],
#         [ 2.6855e-03,  2.2430e-03,  2.4796e-04,  ...,  1.2665e-03,
#          -2.8076e-03, -4.0817e-04],
#         [ 2.6703e-04, -3.3188e-04,  2.3937e-04,  ...,  2.4261e-03,
#           1.1673e-03,  2.0752e-03]], dtype=torch.bfloat16))
# ('model.layers.1.post_attention_layernorm.weight', tensor([0.6406, 0.6328, 0.6484,  ..., 0.6289, 0.6523, 0.6445],
#        dtype=torch.bfloat16))
# ('model.layers.1.self_attn.k_proj.weight', tensor([[-2.3499e-03,  1.0620e-02, -3.6716e-05,  ..., -3.3569e-03,
#           4.7112e-04,  2.4109e-03],
#         [ 9.1076e-05,  4.1504e-03,  1.0967e-04,  ...,  4.6730e-04,
#          -6.8054e-03,  2.7008e-03],
#         [-2.1973e-03,  3.5095e-03,  1.2684e-04,  ..., -1.5564e-03,
#           1.8463e-03, -4.5967e-04],
#         ...,
#         [ 2.1057e-03, -1.9531e-03, -7.9274e-06,  ..., -2.0905e-03,
#          -1.7319e-03, -1.8005e-03],
#         [ 1.8311e-03,  2.4109e-03,  5.9128e-05,  ..., -1.5640e-03,
#           2.2888e-03,  3.6316e-03],
#         [ 6.8970e-03, -1.0681e-03, -5.1856e-06,  ...,  2.7313e-03,
#           1.7471e-03, -9.6130e-04]], dtype=torch.bfloat16))
# ('model.layers.1.self_attn.o_proj.weight', tensor([[ 0.0005, -0.0003, -0.0018,  ..., -0.0014,  0.0010,  0.0007],
#         [-0.0039, -0.0010, -0.0013,  ..., -0.0028,  0.0017,  0.0013],
#         [ 0.0012, -0.0005,  0.0019,  ...,  0.0029, -0.0030, -0.0004],
#         ...,
#         [-0.0009, -0.0031, -0.0027,  ...,  0.0015, -0.0022,  0.0018],
#         [ 0.0004,  0.0014,  0.0002,  ...,  0.0087,  0.0008, -0.0023],
#         [-0.0004,  0.0027,  0.0002,  ...,  0.0052, -0.0028, -0.0017]],
#        dtype=torch.bfloat16))
# ('model.layers.1.self_attn.q_proj.weight', tensor([[ 2.4796e-04, -1.8845e-03,  3.3826e-06,  ...,  2.1820e-03,
#           4.2534e-04,  2.6245e-03],
#         [-1.0109e-04, -1.0452e-03,  4.3631e-05,  ..., -1.6327e-03,
#           1.8158e-03, -1.4019e-04],
#         [ 2.7924e-03, -2.1057e-03, -2.1100e-05,  ...,  2.7466e-03,
#          -3.7384e-03,  9.5749e-04],
#         ...,
#         [ 1.7624e-03, -3.2349e-03,  2.6971e-06,  ..., -2.8839e-03,
#          -6.5002e-03, -1.6785e-03],
#         [ 2.0447e-03,  5.8899e-03, -1.3225e-07,  ..., -1.4019e-04,
#           4.5776e-03,  1.0071e-03],
#         [ 5.4932e-03, -2.5787e-03, -2.8312e-06,  ..., -2.9602e-03,
#          -6.8359e-03, -2.3041e-03]], dtype=torch.bfloat16))
# ('model.layers.1.self_attn.v_proj.weight', tensor([[-5.0964e-03, -2.8076e-03, -2.0504e-04,  ...,  5.4932e-04,
#           5.2643e-04, -2.1820e-03],
#         [ 3.7842e-03, -5.0735e-04,  2.9922e-05,  ..., -6.5308e-03,
#           4.4060e-04, -3.3569e-03],
#         [-7.4768e-04,  1.3809e-03,  1.7262e-04,  ...,  2.1210e-03,
#          -2.9182e-04,  2.8839e-03],
#         ...,
#         [-2.3346e-03, -4.0588e-03,  2.2793e-04,  ..., -3.1586e-03,
#           4.4861e-03, -1.1215e-03],
#         [ 6.1798e-04, -3.9062e-03, -1.2875e-04,  ..., -7.2002e-05,
#          -1.3275e-03,  3.5400e-03],
#         [ 1.0347e-04,  1.6022e-03,  2.4986e-04,  ...,  8.8501e-04,
#          -1.2207e-03,  1.0452e-03]], dtype=torch.bfloat16))
# ('model.layers.10.input_layernorm.weight', tensor([1.4141, 1.6641, 1.8672,  ..., 1.2031, 1.4609, 1.5703],
#        dtype=torch.bfloat16))
# ('model.layers.10.mlp.down_proj.weight', tensor([[-1.6785e-03,  4.4250e-03,  1.0452e-03,  ..., -1.1206e-04,
#           5.1498e-04,  6.1951e-03],
#         [-2.5330e-03,  2.7008e-03,  1.5945e-03,  ..., -1.8082e-03,
#           2.4033e-04, -3.1586e-03],
#         [ 2.5635e-03,  1.4114e-03, -3.7842e-03,  ...,  1.3580e-03,
#          -2.5940e-03,  3.9368e-03],
#         ...,
#         [-2.2430e-03, -3.1433e-03,  3.0823e-03,  ..., -3.0518e-05,
#          -1.2875e-04, -6.0120e-03],
#         [ 1.0910e-03, -2.0294e-03, -1.8234e-03,  ..., -1.9226e-03,
#          -5.2795e-03, -1.0681e-03],
#         [ 1.3123e-03, -2.6703e-03,  1.0757e-03,  ..., -4.4556e-03,
#           1.0529e-03, -2.4261e-03]], dtype=torch.bfloat16))
# ('model.layers.10.mlp.gate_proj.weight', tensor([[ 1.1292e-03,  5.6458e-04, -3.8910e-03,  ...,  2.5024e-03,
#          -2.1667e-03,  1.7071e-04],
#         [ 3.4637e-03,  1.5335e-03, -6.0730e-03,  ..., -5.3406e-03,
#          -3.5553e-03,  2.8992e-04],
#         [ 5.4932e-03, -1.2207e-04,  4.9438e-03,  ...,  2.8381e-03,
#           6.3171e-03,  2.3041e-03],
#         ...,
#         [ 1.7929e-03, -1.2589e-03,  3.2349e-03,  ..., -1.9455e-03,
#          -6.0272e-04, -2.3804e-03],
#         [-2.5177e-04,  5.6076e-04, -2.4719e-03,  ..., -1.0376e-03,
#           4.2725e-03, -1.9226e-03],
#         [-1.2398e-04,  9.8419e-04,  4.2152e-04,  ...,  2.9802e-05,
#           4.0627e-04, -6.3477e-03]], dtype=torch.bfloat16))
# ('model.layers.10.mlp.up_proj.weight', tensor([[ 1.5640e-03,  8.3008e-03, -3.5553e-03,  ...,  7.9346e-03,
#           2.8534e-03, -1.6174e-03],
#         [-2.9297e-03,  6.7139e-04,  2.4872e-03,  ..., -4.2114e-03,
#          -7.0953e-04, -4.1809e-03],
#         [ 4.0588e-03,  6.0425e-03, -5.2185e-03,  ...,  8.5068e-04,
#           1.1673e-03,  1.5182e-03],
#         ...,
#         [ 2.8076e-03, -3.8605e-03,  3.2501e-03,  ..., -2.2736e-03,
#           1.6403e-03,  2.1210e-03],
#         [-3.9368e-03,  6.2561e-04, -6.0425e-03,  ...,  1.3428e-03,
#          -9.8419e-04, -5.8746e-04],
#         [ 2.4109e-03,  7.8583e-04,  2.1553e-04,  ...,  7.6294e-04,
#          -1.9908e-05,  1.0376e-03]], dtype=torch.bfloat16))
# ('model.layers.10.post_attention_layernorm.weight', tensor([1.4297, 1.8125, 1.8125,  ..., 1.3438, 1.4609, 1.5547],
#        dtype=torch.bfloat16))
# ('model.layers.10.self_attn.k_proj.weight', tensor([[ 0.0037, -0.0032, -0.0028,  ...,  0.0009, -0.0006, -0.0002],
#         [-0.0026, -0.0051, -0.0077,  ...,  0.0039,  0.0052, -0.0022],
#         [-0.0012,  0.0019, -0.0022,  ..., -0.0112, -0.0017,  0.0003],
#         ...,
#         [-0.0074, -0.0021, -0.0031,  ...,  0.0034,  0.0050, -0.0087],
#         [-0.0058, -0.0076,  0.0060,  ..., -0.0031, -0.0094,  0.0038],
#         [ 0.0036,  0.0125,  0.0092,  ..., -0.0034, -0.0026, -0.0081]],
#        dtype=torch.bfloat16))
# ('model.layers.10.self_attn.o_proj.weight', tensor([[ 4.5776e-03, -3.6430e-04,  1.0834e-03,  ..., -2.5482e-03,
#           1.5869e-03, -1.4648e-03],
#         [ 3.2959e-03, -3.1586e-03, -2.6550e-03,  ...,  6.4373e-05,
#           2.8729e-05, -3.3569e-03],
#         [ 2.8076e-03, -1.1139e-03, -2.5368e-04,  ..., -3.9978e-03,
#           6.6528e-03,  2.6093e-03],
#         ...,
#         [ 2.7771e-03,  1.0014e-04,  3.5095e-04,  ..., -1.2589e-03,
#           1.6174e-03,  6.8665e-04],
#         [ 4.2419e-03,  1.3447e-04, -1.7166e-03,  ..., -1.3657e-03,
#          -2.8687e-03, -1.4496e-03],
#         [-9.2316e-04,  1.9379e-03,  6.7902e-04,  ...,  3.0365e-03,
#           2.2278e-03,  8.6594e-04]], dtype=torch.bfloat16))
# ('model.layers.10.self_attn.q_proj.weight', tensor([[-1.6479e-03,  8.0109e-04, -2.1820e-03,  ..., -2.2583e-03,
#          -6.9046e-04, -3.9482e-04],
#         [-2.2888e-03, -1.3657e-03,  4.6730e-04,  ..., -2.5024e-03,
#          -1.3199e-03,  2.2583e-03],
#         [ 6.7520e-04, -4.6692e-03, -2.3041e-03,  ..., -2.6093e-03,
#           8.3923e-05,  8.6060e-03],
#         ...,
#         [-5.3406e-03, -2.2602e-04, -2.5024e-03,  ..., -7.6294e-04,
#          -5.0049e-03,  5.2795e-03],
#         [-1.2360e-03, -3.4027e-03, -2.8229e-03,  ...,  1.2146e-02,
#          -1.2589e-03, -3.0365e-03],
#         [ 1.9684e-03,  1.3657e-03, -4.2114e-03,  ...,  5.7678e-03,
#           3.1738e-03, -6.7139e-04]], dtype=torch.bfloat16))
# ('model.layers.10.self_attn.v_proj.weight', tensor([[-8.4839e-03, -6.7749e-03,  3.5524e-05,  ..., -8.6212e-04,
#          -3.0212e-03,  1.9531e-03],
#         [ 1.5030e-03,  1.9684e-03, -9.4223e-04,  ...,  5.0659e-03,
#           8.6060e-03, -1.8234e-03],
#         [ 3.7193e-04,  3.6163e-03,  3.4180e-03,  ...,  1.5259e-04,
#           2.4414e-03, -1.4496e-03],
#         ...,
#         [-1.3199e-03,  3.7842e-03, -5.2490e-03,  ...,  7.0572e-04,
#           6.8665e-05,  2.9945e-04],
#         [-5.6839e-04, -2.6398e-03, -4.8828e-04,  ...,  6.9809e-04,
#          -1.5545e-04,  2.0599e-03],
#         [-1.6632e-03,  5.6839e-04,  3.5858e-03,  ..., -4.8218e-03,
#           1.9684e-03, -2.1973e-03]], dtype=torch.bfloat16))
# ('model.layers.11.input_layernorm.weight', tensor([1.6016, 2.1250, 2.1094,  ..., 1.3125, 1.6797, 1.7266],
#        dtype=torch.bfloat16))
# ('model.layers.11.mlp.down_proj.weight', tensor([[ 3.3875e-03,  2.6550e-03, -1.7090e-03,  ...,  4.9744e-03,
#           1.5488e-03, -9.0790e-04],
#         [ 8.0872e-04, -6.1646e-03,  2.0905e-03,  ...,  4.0588e-03,
#           6.3419e-05, -2.7466e-03],
#         [ 2.3346e-03,  7.6675e-04, -7.0572e-05,  ...,  1.8158e-03,
#           1.3046e-03,  1.1749e-03],
#         ...,
#         [ 3.4332e-04,  3.0975e-03,  5.8746e-04,  ...,  1.8082e-03,
#          -1.8692e-04,  4.3488e-04],
#         [ 5.7983e-04, -2.9602e-03,  4.8828e-03,  ..., -6.5308e-03,
#           6.3705e-04,  2.6245e-03],
#         [-2.8229e-03, -2.3804e-03,  3.1891e-03,  ...,  2.1362e-03,
#          -2.2888e-03, -3.6926e-03]], dtype=torch.bfloat16))
# ('model.layers.11.mlp.gate_proj.weight', tensor([[-3.7384e-03,  1.5259e-03, -3.0365e-03,  ..., -3.5286e-04,
#          -8.2493e-05,  6.7520e-04],
#         [-6.1035e-03,  6.3477e-03, -1.7929e-03,  ..., -4.1199e-03,
#           2.5635e-03,  5.4321e-03],
#         [ 1.5163e-04, -8.0872e-04,  5.2490e-03,  ..., -2.8801e-04,
#           2.1267e-04, -1.0910e-03],
#         ...,
#         [ 1.4038e-03, -1.7624e-03,  1.9455e-03,  ...,  8.8120e-04,
#           3.0365e-03, -1.5793e-03],
#         [ 2.6093e-03, -2.5330e-03,  4.3945e-03,  ...,  5.8594e-03,
#           1.9379e-03,  3.9978e-03],
#         [ 1.4267e-03, -1.3542e-04, -1.2131e-03,  ...,  3.6621e-03,
#          -5.5313e-04, -3.0670e-03]], dtype=torch.bfloat16))
# ('model.layers.11.mlp.up_proj.weight', tensor([[ 3.4637e-03, -3.0212e-03, -3.5248e-03,  ...,  1.6632e-03,
#           1.4973e-04, -3.8300e-03],
#         [ 3.7994e-03, -5.7373e-03, -4.0894e-03,  ...,  4.9133e-03,
#           4.6539e-04, -2.8968e-05],
#         [-1.3199e-03,  7.3624e-04,  8.6594e-04,  ..., -5.0354e-03,
#           7.1716e-03,  1.1063e-03],
#         ...,
#         [ 1.6937e-03,  2.9602e-03,  7.9727e-04,  ...,  3.5400e-03,
#          -2.6321e-04,  3.7193e-04],
#         [-8.5068e-04, -6.7749e-03, -1.5488e-03,  ..., -2.2984e-04,
#          -2.0142e-03,  2.7008e-03],
#         [ 2.8076e-03, -6.8054e-03,  3.3875e-03,  ...,  4.1199e-03,
#          -5.5847e-03, -3.9368e-03]], dtype=torch.bfloat16))
# ('model.layers.11.post_attention_layernorm.weight', tensor([1.4922, 2.0625, 1.8828,  ..., 1.3750, 1.4922, 1.6016],
#        dtype=torch.bfloat16))
# ('model.layers.11.self_attn.k_proj.weight', tensor([[ 0.0011, -0.0015,  0.0030,  ...,  0.0009,  0.0066,  0.0041],
#         [-0.0031, -0.0026,  0.0010,  ..., -0.0034, -0.0020, -0.0016],
#         [-0.0009,  0.0088, -0.0016,  ...,  0.0015, -0.0034, -0.0012],
#         ...,
#         [ 0.0066, -0.0063, -0.0015,  ...,  0.0052,  0.0060, -0.0011],
#         [ 0.0002,  0.0115, -0.0066,  ..., -0.0019, -0.0020,  0.0028],
#         [ 0.0015,  0.0088,  0.0134,  ..., -0.0034,  0.0095, -0.0049]],
#        dtype=torch.bfloat16))
# ('model.layers.11.self_attn.o_proj.weight', tensor([[-0.0004, -0.0014,  0.0025,  ..., -0.0010,  0.0012, -0.0014],
#         [ 0.0010,  0.0024,  0.0027,  ..., -0.0023, -0.0022,  0.0038],
#         [-0.0030, -0.0046, -0.0038,  ..., -0.0001, -0.0009,  0.0006],
#         ...,
#         [ 0.0009,  0.0028, -0.0047,  ..., -0.0003, -0.0038,  0.0020],
#         [-0.0035,  0.0016, -0.0021,  ...,  0.0004,  0.0007,  0.0051],
#         [-0.0002, -0.0044, -0.0004,  ..., -0.0012, -0.0017,  0.0007]],
#        dtype=torch.bfloat16))
# ('model.layers.11.self_attn.q_proj.weight', tensor([[-2.0294e-03, -2.5940e-03,  5.8365e-04,  ..., -1.2283e-03,
#           7.4387e-04, -9.1934e-04],
#         [-2.1057e-03, -3.9978e-03, -9.7752e-06,  ..., -2.1515e-03,
#           1.5030e-03,  3.7842e-03],
#         [-4.5967e-04, -2.1362e-03,  1.0452e-03,  ..., -5.4932e-04,
#           5.1498e-04,  1.8082e-03],
#         ...,
#         [-2.5177e-03,  3.2654e-03,  2.5482e-03,  ...,  2.5330e-03,
#          -2.8534e-03, -6.2561e-03],
#         [-2.5940e-04, -6.9885e-03, -2.5177e-03,  ...,  1.0605e-03,
#           1.5411e-03, -2.9144e-03],
#         [-2.0752e-03, -2.2430e-03, -1.4801e-03,  ..., -3.5667e-04,
#          -8.1253e-04, -3.1433e-03]], dtype=torch.bfloat16))
# ('model.layers.11.self_attn.v_proj.weight', tensor([[-0.0005, -0.0052, -0.0016,  ..., -0.0028, -0.0026, -0.0013],
#         [-0.0053, -0.0033,  0.0103,  ..., -0.0018,  0.0013, -0.0030],
#         [ 0.0025, -0.0012,  0.0046,  ..., -0.0022, -0.0044, -0.0010],
#         ...,
#         [ 0.0012,  0.0023,  0.0004,  ..., -0.0043, -0.0024,  0.0005],
#         [ 0.0028,  0.0017, -0.0002,  ...,  0.0022, -0.0004, -0.0003],
#         [ 0.0043, -0.0019,  0.0021,  ..., -0.0029, -0.0018, -0.0001]],
#        dtype=torch.bfloat16))
# ('model.layers.12.input_layernorm.weight', tensor([1.7344, 2.2812, 2.3594,  ..., 1.4531, 1.7891, 1.9453],
#        dtype=torch.bfloat16))
# ('model.layers.12.mlp.down_proj.weight', tensor([[ 2.6703e-03, -1.1749e-03,  5.2643e-04,  ...,  1.9684e-03,
#           3.4790e-03,  5.9814e-03],
#         [-7.6675e-04,  2.4872e-03,  4.0588e-03,  ..., -2.0294e-03,
#          -3.1281e-03,  3.2349e-03],
#         [ 1.2934e-05,  2.4261e-03,  7.1106e-03,  ..., -2.5177e-04,
#           3.1281e-03, -3.2196e-03],
#         ...,
#         [ 2.3804e-03,  1.7834e-04,  7.0095e-05,  ...,  1.9226e-03,
#           4.2419e-03,  1.6479e-03],
#         [ 4.6387e-03, -2.1210e-03, -6.2561e-04,  ...,  1.7166e-03,
#           2.7008e-03, -1.9455e-03],
#         [ 5.5313e-04,  3.4637e-03, -3.6469e-03,  ...,  2.8381e-03,
#          -5.2490e-03,  1.8692e-03]], dtype=torch.bfloat16))
# ('model.layers.12.mlp.gate_proj.weight', tensor([[-0.0024, -0.0017,  0.0020,  ..., -0.0010,  0.0012,  0.0009],
#         [ 0.0031, -0.0002, -0.0050,  ..., -0.0017,  0.0005, -0.0030],
#         [ 0.0054,  0.0011,  0.0052,  ..., -0.0016, -0.0032, -0.0023],
#         ...,
#         [ 0.0036,  0.0020, -0.0021,  ...,  0.0007,  0.0051,  0.0002],
#         [-0.0055, -0.0040,  0.0056,  ...,  0.0025,  0.0039,  0.0004],
#         [ 0.0034,  0.0049,  0.0002,  ..., -0.0001,  0.0007,  0.0023]],
#        dtype=torch.bfloat16))
# ('model.layers.12.mlp.up_proj.weight', tensor([[ 2.0447e-03, -3.4485e-03,  2.2583e-03,  ..., -2.4261e-03,
#          -8.0490e-04, -2.3937e-04],
#         [-1.7624e-03,  2.7924e-03, -3.3875e-03,  ..., -2.3651e-03,
#           3.0365e-03, -2.2030e-04],
#         [ 1.4420e-03,  1.7700e-03, -3.7537e-03,  ..., -1.0757e-03,
#          -2.1057e-03, -1.0834e-03],
#         ...,
#         [ 4.2725e-03,  1.8997e-03, -4.7922e-05,  ..., -1.6975e-04,
#          -1.9989e-03,  4.6387e-03],
#         [ 2.4872e-03,  2.1210e-03, -2.7313e-03,  ...,  3.2196e-03,
#          -5.1498e-04, -1.4343e-03],
#         [ 6.6528e-03,  7.4463e-03, -8.2397e-03,  ...,  4.6387e-03,
#          -4.5776e-03,  9.6893e-04]], dtype=torch.bfloat16))
# ('model.layers.12.post_attention_layernorm.weight', tensor([1.6172, 2.3594, 2.1094,  ..., 1.4375, 1.6328, 1.7500],
#        dtype=torch.bfloat16))
# ('model.layers.12.self_attn.k_proj.weight', tensor([[-1.9150e-03, -3.3264e-03,  4.9973e-04,  ..., -4.0054e-05,
#           1.1969e-04,  5.5542e-03],
#         [-1.9226e-03,  1.1368e-03,  6.2943e-04,  ...,  7.4768e-04,
#          -1.9684e-03, -5.5847e-03],
#         [-1.2493e-04, -2.4261e-03,  4.9591e-04,  ..., -1.1368e-03,
#           1.1749e-03, -7.6675e-04],
#         ...,
#         [-3.2196e-03, -2.8687e-03,  2.3346e-03,  ...,  7.2098e-04,
#           8.8120e-04, -3.9368e-03],
#         [-4.2915e-04, -1.3733e-03,  4.8065e-04,  ..., -1.4114e-04,
#           1.4343e-03, -2.0294e-03],
#         [-7.1716e-03,  1.7242e-03, -5.1880e-03,  ...,  1.8082e-03,
#           1.3351e-03, -5.1575e-03]], dtype=torch.bfloat16))
# ('model.layers.12.self_attn.o_proj.weight', tensor([[-0.0030,  0.0013, -0.0008,  ...,  0.0018,  0.0031,  0.0005],
#         [ 0.0033,  0.0006, -0.0048,  ..., -0.0017, -0.0011,  0.0006],
#         [ 0.0002, -0.0015, -0.0013,  ..., -0.0063, -0.0015, -0.0036],
#         ...,
#         [-0.0010,  0.0017, -0.0012,  ...,  0.0012, -0.0018, -0.0022],
#         [ 0.0001, -0.0029, -0.0023,  ...,  0.0006,  0.0045,  0.0025],
#         [ 0.0014,  0.0031, -0.0017,  ..., -0.0005, -0.0055,  0.0009]],
#        dtype=torch.bfloat16))
# ('model.layers.12.self_attn.q_proj.weight', tensor([[-4.4556e-03, -3.0975e-03, -3.1281e-03,  ..., -4.4346e-05,
#           1.5488e-03, -7.3242e-04],
#         [ 4.2419e-03, -7.3853e-03,  9.1934e-04,  ..., -3.0365e-03,
#          -3.9368e-03, -2.3499e-03],
#         [-1.7395e-03, -7.2937e-03, -3.7994e-03,  ...,  1.1063e-03,
#          -1.7395e-03,  2.0142e-03],
#         ...,
#         [-6.3477e-03,  6.2180e-04,  3.5400e-03,  ..., -1.6403e-03,
#          -3.6316e-03,  2.0752e-03],
#         [-5.1270e-03,  3.1891e-03, -7.7057e-04,  ...,  5.3406e-03,
#           5.1270e-03,  1.7624e-03],
#         [-8.5354e-05,  3.5095e-03,  2.4109e-03,  ..., -1.0529e-03,
#          -4.7607e-03,  4.3945e-03]], dtype=torch.bfloat16))
# ('model.layers.12.self_attn.v_proj.weight', tensor([[ 1.3809e-03, -1.0605e-03, -2.2278e-03,  ...,  4.6349e-04,
#          -3.0041e-05,  1.5945e-03],
#         [ 1.0157e-04,  3.7231e-03, -1.8387e-03,  ..., -1.4648e-03,
#          -2.2583e-03,  2.2030e-04],
#         [-2.2697e-04,  1.8234e-03, -1.7166e-03,  ..., -3.9062e-03,
#          -2.0599e-03,  2.3346e-03],
#         ...,
#         [ 1.4801e-03, -4.7607e-03, -1.4420e-03,  ..., -1.1368e-03,
#          -2.6703e-03, -4.1809e-03],
#         [ 3.6316e-03, -3.3875e-03, -1.7242e-03,  ..., -8.4877e-05,
#          -4.9973e-04, -6.5231e-04],
#         [ 2.7771e-03, -1.1597e-03, -7.6904e-03,  ...,  2.5024e-03,
#          -1.6174e-03, -1.9684e-03]], dtype=torch.bfloat16))
# ('model.layers.13.input_layernorm.weight', tensor([1.7891, 2.7031, 2.6250,  ..., 1.4219, 1.7891, 2.0781],
#        dtype=torch.bfloat16))
# ('model.layers.13.mlp.down_proj.weight', tensor([[-6.8665e-04,  8.2397e-04,  2.6131e-04,  ..., -1.5717e-03,
#          -2.3346e-03,  2.6855e-03],
#         [ 7.7057e-04,  6.5804e-05,  1.2207e-03,  ..., -5.9814e-03,
#           2.0599e-03, -1.7319e-03],
#         [ 1.1749e-03, -2.7924e-03,  3.5706e-03,  ...,  9.3460e-05,
#           3.4180e-03, -3.7994e-03],
#         ...,
#         [-9.8419e-04, -3.0060e-03, -3.5553e-03,  ..., -3.1281e-04,
#           2.5635e-03,  1.2894e-03],
#         [ 2.1667e-03,  4.5166e-03,  4.2419e-03,  ..., -2.4261e-03,
#          -2.7313e-03, -3.6163e-03],
#         [-1.6251e-03,  1.6556e-03, -9.1553e-04,  ..., -1.6174e-03,
#           1.3809e-03,  2.4414e-04]], dtype=torch.bfloat16))
# ('model.layers.13.mlp.gate_proj.weight', tensor([[-2.5177e-03, -6.4468e-04,  2.1515e-03,  ...,  3.1281e-03,
#           1.1597e-03,  1.5259e-03],
#         [-5.9509e-03,  5.5695e-04, -1.8845e-03,  ..., -2.8534e-03,
#          -5.1558e-06, -2.3804e-03],
#         [-9.6436e-03,  4.9744e-03,  3.8147e-03,  ..., -8.7738e-04,
#           4.0894e-03,  3.6621e-03],
#         ...,
#         [-5.6839e-04, -5.9814e-03,  1.3733e-04,  ..., -3.6926e-03,
#           1.5106e-03, -3.0060e-03],
#         [ 2.5635e-03,  2.4414e-04, -2.6512e-04,  ...,  2.4719e-03,
#          -2.4109e-03,  9.3842e-04],
#         [-4.8218e-03,  1.0147e-03, -2.5940e-03,  ..., -2.7008e-03,
#          -2.8076e-03,  5.7678e-03]], dtype=torch.bfloat16))
# ('model.layers.13.mlp.up_proj.weight', tensor([[-2.3651e-03,  2.8419e-04,  1.9836e-04,  ...,  2.6398e-03,
#          -2.2278e-03,  1.6689e-04],
#         [ 2.5940e-03,  2.4567e-03,  7.7438e-04,  ..., -2.2736e-03,
#           4.4556e-03,  3.1090e-04],
#         [-3.8757e-03, -2.1362e-03,  5.4321e-03,  ...,  9.3079e-04,
#           3.6316e-03, -4.8218e-03],
#         ...,
#         [ 2.3041e-03, -9.0332e-03, -2.8419e-04,  ...,  2.2736e-03,
#           3.7193e-05,  4.9973e-04],
#         [-9.4223e-04,  4.1809e-03, -4.9973e-04,  ..., -2.7466e-03,
#           8.0490e-04, -2.0142e-03],
#         [-3.1433e-03, -2.1515e-03, -1.1749e-03,  ...,  9.1171e-04,
#           1.8234e-03,  5.3101e-03]], dtype=torch.bfloat16))
# ('model.layers.13.post_attention_layernorm.weight', tensor([1.7344, 2.7188, 2.2344,  ..., 1.5391, 1.7031, 1.8203],
#        dtype=torch.bfloat16))
# ('model.layers.13.self_attn.k_proj.weight', tensor([[ 0.0034, -0.0069, -0.0035,  ..., -0.0012, -0.0063,  0.0029],
#         [ 0.0004, -0.0040,  0.0017,  ..., -0.0037,  0.0074,  0.0025],
#         [ 0.0005, -0.0013,  0.0023,  ...,  0.0017,  0.0053,  0.0013],
#         ...,
#         [ 0.0082, -0.0029, -0.0033,  ..., -0.0006, -0.0012, -0.0060],
#         [-0.0059, -0.0052, -0.0033,  ...,  0.0004,  0.0026,  0.0029],
#         [ 0.0041, -0.0063, -0.0036,  ..., -0.0056,  0.0007,  0.0026]],
#        dtype=torch.bfloat16))
# ('model.layers.13.self_attn.o_proj.weight', tensor([[ 5.0354e-04, -6.1989e-05,  4.7913e-03,  ..., -4.0588e-03,
#          -9.0027e-04, -1.4572e-03],
#         [ 3.6774e-03, -1.8005e-03, -1.8539e-03,  ..., -1.6785e-03,
#          -3.3112e-03, -4.1771e-04],
#         [ 5.9509e-04, -1.6594e-04,  3.6926e-03,  ..., -3.2806e-03,
#           1.2054e-03,  3.7575e-04],
#         ...,
#         [ 3.0670e-03, -1.9836e-03,  3.3569e-03,  ...,  4.1199e-03,
#          -6.4087e-04, -7.2861e-04],
#         [-1.4267e-03, -2.6245e-03, -3.8300e-03,  ...,  1.1902e-03,
#          -6.1798e-04,  4.3335e-03],
#         [-1.2894e-03, -1.9684e-03, -5.1880e-03,  ...,  5.7220e-04,
#          -4.6997e-03,  1.3123e-03]], dtype=torch.bfloat16))
# ('model.layers.13.self_attn.q_proj.weight', tensor([[-4.4632e-04,  6.7139e-03,  3.6774e-03,  ...,  4.1389e-04,
#           1.3504e-03, -5.3406e-04],
#         [-6.8665e-04, -5.9814e-03,  3.6469e-03,  ...,  3.1281e-03,
#           3.2196e-03, -1.0376e-03],
#         [ 4.5471e-03,  6.9275e-03,  3.1586e-03,  ...,  1.3504e-03,
#          -1.7853e-03, -2.9182e-04],
#         ...,
#         [ 1.8845e-03,  4.8523e-03,  2.1973e-03,  ..., -1.3769e-05,
#          -5.8746e-04,  4.4861e-03],
#         [ 1.0605e-03, -7.3433e-05,  3.6316e-03,  ..., -3.1662e-04,
#           1.1215e-03, -2.6550e-03],
#         [-4.7913e-03,  1.7929e-03,  3.7766e-04,  ...,  2.0294e-03,
#          -7.8201e-04, -3.6926e-03]], dtype=torch.bfloat16))
# ('model.layers.13.self_attn.v_proj.weight', tensor([[ 0.0007, -0.0013,  0.0008,  ...,  0.0006, -0.0022,  0.0005],
#         [ 0.0016, -0.0037, -0.0037,  ...,  0.0002, -0.0010,  0.0009],
#         [ 0.0005,  0.0007,  0.0059,  ...,  0.0020, -0.0002, -0.0041],
#         ...,
#         [-0.0001, -0.0008, -0.0008,  ...,  0.0024,  0.0028, -0.0001],
#         [-0.0008,  0.0015, -0.0010,  ..., -0.0051, -0.0019, -0.0029],
#         [ 0.0051,  0.0049, -0.0023,  ..., -0.0045, -0.0013,  0.0008]],
#        dtype=torch.bfloat16))
# ('model.layers.14.input_layernorm.weight', tensor([1.9688, 2.9375, 2.7656,  ..., 1.5391, 1.8984, 2.1875],
#        dtype=torch.bfloat16))
# ('model.layers.14.mlp.down_proj.weight', tensor([[-0.0005,  0.0052,  0.0007,  ..., -0.0007,  0.0016,  0.0016],
#         [-0.0022, -0.0026, -0.0007,  ...,  0.0038, -0.0009,  0.0048],
#         [ 0.0037, -0.0064,  0.0003,  ...,  0.0002, -0.0073,  0.0030],
#         ...,
#         [ 0.0025,  0.0025,  0.0036,  ..., -0.0043,  0.0029, -0.0038],
#         [ 0.0034,  0.0012, -0.0017,  ...,  0.0016, -0.0021, -0.0012],
#         [-0.0018,  0.0006, -0.0021,  ..., -0.0006, -0.0021,  0.0015]],
#        dtype=torch.bfloat16))
# ('model.layers.14.mlp.gate_proj.weight', tensor([[-4.6692e-03, -3.3875e-03, -2.8687e-03,  ...,  4.3335e-03,
#           5.3406e-03,  6.3171e-03],
#         [ 2.4223e-04,  1.8692e-03, -5.2490e-03,  ..., -4.3335e-03,
#           4.6082e-03, -3.1281e-03],
#         [-2.6703e-03,  2.2888e-03, -4.1199e-03,  ...,  7.2956e-05,
#           1.9531e-03, -4.2114e-03],
#         ...,
#         [-1.9150e-03,  1.3199e-03,  4.0283e-03,  ...,  8.6670e-03,
#           8.6060e-03,  2.3499e-03],
#         [ 2.0905e-03, -7.2098e-04,  1.0071e-03,  ..., -1.4019e-04,
#          -1.5869e-03, -4.6387e-03],
#         [-4.9133e-03, -6.1417e-04, -2.1973e-03,  ..., -1.7071e-04,
#           1.2741e-03,  1.2283e-03]], dtype=torch.bfloat16))
# ('model.layers.14.mlp.up_proj.weight', tensor([[-0.0002,  0.0033, -0.0010,  ...,  0.0038,  0.0021,  0.0029],
#         [ 0.0031, -0.0069, -0.0028,  ...,  0.0011,  0.0027, -0.0009],
#         [ 0.0003, -0.0027,  0.0007,  ..., -0.0011, -0.0031,  0.0018],
#         ...,
#         [ 0.0032,  0.0031,  0.0024,  ...,  0.0015,  0.0010,  0.0030],
#         [-0.0018,  0.0027,  0.0042,  ...,  0.0009, -0.0037, -0.0049],
#         [ 0.0044, -0.0013,  0.0027,  ..., -0.0038,  0.0020, -0.0034]],
#        dtype=torch.bfloat16))
# ('model.layers.14.post_attention_layernorm.weight', tensor([1.7812, 3.1094, 2.2969,  ..., 1.6328, 1.7734, 1.8750],
#        dtype=torch.bfloat16))
# ('model.layers.14.self_attn.k_proj.weight', tensor([[ 0.0007, -0.0016, -0.0005,  ..., -0.0025, -0.0004, -0.0020],
#         [-0.0014,  0.0007, -0.0003,  ..., -0.0035,  0.0024,  0.0017],
#         [-0.0013, -0.0004, -0.0011,  ...,  0.0009, -0.0017,  0.0014],
#         ...,
#         [ 0.0057,  0.0015,  0.0030,  ...,  0.0027, -0.0036, -0.0016],
#         [-0.0015, -0.0041,  0.0007,  ..., -0.0045, -0.0144,  0.0032],
#         [-0.0039,  0.0006,  0.0048,  ..., -0.0020,  0.0057, -0.0015]],
#        dtype=torch.bfloat16))
# ('model.layers.14.self_attn.o_proj.weight', tensor([[-1.7395e-03, -1.3504e-03,  1.2016e-04,  ...,  1.8845e-03,
#           6.5231e-04,  2.1362e-03],
#         [-1.2131e-03, -2.5635e-03, -1.0986e-03,  ..., -5.0659e-03,
#          -5.2929e-05, -2.4414e-03],
#         [-2.0142e-03, -2.0294e-03,  3.3569e-03,  ...,  3.8719e-04,
#           5.7983e-04, -2.1210e-03],
#         ...,
#         [-7.8201e-04,  1.6708e-03, -8.2397e-04,  ...,  5.6763e-03,
#           3.6011e-03,  2.2278e-03],
#         [ 3.2806e-03,  1.5793e-03,  2.4567e-03,  ...,  1.2207e-03,
#           3.2043e-03,  1.4572e-03],
#         [ 3.1433e-03, -8.8692e-05, -3.0060e-03,  ..., -1.1902e-03,
#          -6.9046e-04, -4.9591e-04]], dtype=torch.bfloat16))
# ('model.layers.14.self_attn.q_proj.weight', tensor([[-4.3945e-03,  4.6082e-03, -2.5330e-03,  ..., -4.6387e-03,
#           1.5450e-04,  4.2419e-03],
#         [ 4.1246e-05,  9.0942e-03,  9.1171e-04,  ..., -2.9564e-04,
#           8.8120e-04, -9.9182e-04],
#         [ 4.6692e-03, -5.2795e-03,  4.4556e-03,  ...,  1.4725e-03,
#           9.5749e-04, -1.6632e-03],
#         ...,
#         [ 9.8419e-04,  5.1880e-04,  1.0193e-02,  ...,  5.6152e-03,
#           9.7046e-03, -5.0659e-03],
#         [ 8.3618e-03,  5.4321e-03, -9.4604e-03,  ...,  1.3885e-03,
#          -1.2024e-02, -9.4986e-04],
#         [-3.2349e-03, -7.9346e-03, -9.9540e-06,  ..., -1.4420e-03,
#          -1.8921e-03,  1.3351e-03]], dtype=torch.bfloat16))
# ('model.layers.14.self_attn.v_proj.weight', tensor([[ 9.6512e-04, -2.3956e-03,  1.6785e-03,  ..., -3.9978e-03,
#          -1.5640e-03,  1.6022e-03],
#         [-3.1281e-03, -5.2691e-05,  3.0060e-03,  ...,  2.1057e-03,
#           1.9531e-03,  1.0452e-03],
#         [-4.3869e-05, -1.8845e-03, -7.3242e-04,  ...,  3.4485e-03,
#          -8.3923e-04,  9.9945e-04],
#         ...,
#         [ 2.5940e-04,  1.9455e-03, -1.2512e-03,  ..., -1.2131e-03,
#          -2.0905e-03, -1.3657e-03],
#         [ 3.5248e-03, -4.3335e-03,  4.0283e-03,  ...,  9.6130e-04,
#           9.1553e-04, -2.3041e-03],
#         [ 5.8365e-04,  2.1458e-04, -5.0354e-04,  ...,  4.6692e-03,
#           1.4267e-03, -2.7924e-03]], dtype=torch.bfloat16))
# ('model.layers.15.input_layernorm.weight', tensor([2.2031, 3.2656, 3.0156,  ..., 1.8672, 2.2188, 2.4219],
#        dtype=torch.bfloat16))
# ('model.layers.15.mlp.down_proj.weight', tensor([[ 6.7520e-04,  1.2131e-03,  2.1667e-03,  ..., -2.3956e-03,
#          -3.4180e-03, -4.7302e-03],
#         [-6.9427e-04,  3.8624e-05,  1.2436e-03,  ..., -1.8997e-03,
#           1.2457e-05,  6.2180e-04],
#         [ 1.5259e-03, -2.4261e-03, -1.4038e-03,  ..., -4.4250e-03,
#          -3.8757e-03, -1.0910e-03],
#         ...,
#         [ 3.8338e-04, -1.8311e-03, -1.3123e-03,  ..., -2.1210e-03,
#          -2.4719e-03,  5.0354e-03],
#         [ 4.3640e-03, -2.5940e-04, -2.8610e-04,  ..., -4.2725e-03,
#           1.1396e-04, -1.9455e-03],
#         [ 4.9591e-04, -3.9673e-04,  1.6689e-04,  ...,  1.1063e-03,
#           5.0735e-04, -3.8528e-04]], dtype=torch.bfloat16))
# ('model.layers.15.mlp.gate_proj.weight', tensor([[ 0.0008, -0.0028, -0.0017,  ...,  0.0040,  0.0031,  0.0011],
#         [-0.0025,  0.0012, -0.0009,  ...,  0.0003, -0.0002,  0.0058],
#         [-0.0013, -0.0021, -0.0004,  ..., -0.0009,  0.0020,  0.0010],
#         ...,
#         [ 0.0031, -0.0009,  0.0009,  ..., -0.0030, -0.0008, -0.0013],
#         [ 0.0011,  0.0006, -0.0005,  ..., -0.0015, -0.0029, -0.0030],
#         [-0.0034,  0.0029, -0.0046,  ..., -0.0001,  0.0006,  0.0004]],
#        dtype=torch.bfloat16))
# ('model.layers.15.mlp.up_proj.weight', tensor([[-0.0012,  0.0044, -0.0017,  ..., -0.0056, -0.0040,  0.0008],
#         [-0.0004,  0.0015, -0.0026,  ..., -0.0040,  0.0038, -0.0006],
#         [ 0.0031, -0.0037, -0.0019,  ..., -0.0018, -0.0002, -0.0027],
#         ...,
#         [-0.0004, -0.0002, -0.0016,  ...,  0.0026, -0.0052,  0.0009],
#         [ 0.0009, -0.0048, -0.0012,  ..., -0.0027, -0.0004,  0.0010],
#         [-0.0019,  0.0030, -0.0026,  ...,  0.0024,  0.0082, -0.0038]],
#        dtype=torch.bfloat16))
# ('model.layers.15.post_attention_layernorm.weight', tensor([1.9531, 3.8281, 2.4219,  ..., 1.8359, 1.9531, 2.0156],
#        dtype=torch.bfloat16))
# ('model.layers.15.self_attn.k_proj.weight', tensor([[ 1.8463e-03, -5.1270e-03,  2.6894e-04,  ..., -1.1492e-04,
#           1.8463e-03,  5.0735e-04],
#         [-2.2736e-03,  3.9978e-03,  2.3270e-04,  ..., -3.4790e-03,
#          -2.6245e-03,  2.4719e-03],
#         [ 1.6022e-03, -6.0730e-03, -5.8289e-03,  ...,  3.4332e-03,
#           6.1417e-04,  7.4387e-04],
#         ...,
#         [-7.4463e-03, -1.0071e-03,  9.7046e-03,  ...,  4.7913e-03,
#           3.5248e-03, -4.8218e-03],
#         [ 4.0283e-03, -4.5538e-05,  2.8534e-03,  ..., -4.9744e-03,
#          -2.6398e-03,  2.4438e-05],
#         [-1.6556e-03, -3.1738e-03,  8.5449e-03,  ...,  4.1809e-03,
#           1.9897e-02,  8.4839e-03]], dtype=torch.bfloat16))
# ('model.layers.15.self_attn.o_proj.weight', tensor([[ 3.6621e-03, -3.6469e-03,  5.6839e-04,  ..., -2.1362e-03,
#           4.1199e-03,  2.9755e-03],
#         [-1.0376e-03,  1.5488e-03, -2.1515e-03,  ...,  4.4250e-03,
#           4.2419e-03,  1.9073e-03],
#         [-6.6280e-05,  2.7924e-03,  2.3804e-03,  ..., -2.4109e-03,
#           4.2419e-03,  3.7231e-03],
#         ...,
#         [-3.1586e-03, -8.3923e-04,  2.7466e-03,  ..., -4.8828e-03,
#          -8.3923e-04, -4.0283e-03],
#         [ 2.2316e-04, -3.7432e-05,  1.5411e-03,  ..., -2.7657e-04,
#          -4.0283e-03,  1.5488e-03],
#         [ 2.9755e-03,  2.7924e-03, -1.3657e-03,  ..., -1.9379e-03,
#          -1.8311e-03,  1.6708e-03]], dtype=torch.bfloat16))
# ('model.layers.15.self_attn.q_proj.weight', tensor([[-0.0008,  0.0027, -0.0001,  ...,  0.0009, -0.0027, -0.0019],
#         [ 0.0004, -0.0039,  0.0012,  ...,  0.0015,  0.0016,  0.0009],
#         [-0.0032,  0.0084,  0.0002,  ...,  0.0019, -0.0023,  0.0012],
#         ...,
#         [-0.0058,  0.0038,  0.0056,  ..., -0.0046,  0.0052,  0.0007],
#         [ 0.0014,  0.0003,  0.0044,  ...,  0.0042, -0.0083,  0.0020],
#         [ 0.0017,  0.0029,  0.0023,  ..., -0.0040,  0.0023, -0.0055]],
#        dtype=torch.bfloat16))
# ('model.layers.15.self_attn.v_proj.weight', tensor([[ 4.6387e-03, -1.7166e-03, -1.8845e-03,  ..., -3.6469e-03,
#           6.3705e-04,  2.5482e-03],
#         [-6.5267e-06,  1.2894e-03,  2.3346e-03,  ..., -1.2817e-03,
#           4.8056e-07,  3.7384e-03],
#         [-7.3242e-04, -4.4556e-03,  3.1433e-03,  ...,  3.0823e-03,
#           5.1270e-03, -1.4343e-03],
#         ...,
#         [ 8.6594e-04, -2.7657e-04, -5.9128e-04,  ..., -3.5553e-03,
#          -2.3651e-03, -1.7548e-03],
#         [ 1.5488e-03, -5.6839e-04,  4.2915e-04,  ..., -2.4872e-03,
#           4.8828e-03,  1.1368e-03],
#         [ 3.1433e-03, -1.0529e-03, -7.7057e-04,  ...,  1.6403e-04,
#           2.0504e-04, -2.2278e-03]], dtype=torch.bfloat16))
# ('model.layers.16.input_layernorm.weight', tensor([2.3594, 3.6875, 2.9688,  ..., 1.9453, 2.2812, 2.4688],
#        dtype=torch.bfloat16))
# ('model.layers.16.mlp.down_proj.weight', tensor([[ 0.0027, -0.0027, -0.0044,  ..., -0.0029, -0.0067, -0.0095],
#         [-0.0076,  0.0060,  0.0010,  ..., -0.0042,  0.0006,  0.0020],
#         [-0.0039, -0.0014, -0.0002,  ..., -0.0026,  0.0012,  0.0040],
#         ...,
#         [ 0.0055,  0.0011,  0.0016,  ..., -0.0024,  0.0005, -0.0052],
#         [-0.0014, -0.0017, -0.0082,  ..., -0.0016,  0.0002, -0.0005],
#         [-0.0052,  0.0020,  0.0032,  ..., -0.0046, -0.0015, -0.0022]],
#        dtype=torch.bfloat16))
# ('model.layers.16.mlp.gate_proj.weight', tensor([[-2.8687e-03, -4.2114e-03,  1.2436e-03,  ..., -6.0730e-03,
#          -3.7956e-04, -4.3640e-03],
#         [ 3.8452e-03,  2.8381e-03,  6.9809e-04,  ...,  2.8229e-03,
#           4.7913e-03, -3.1281e-03],
#         [ 2.5940e-03, -1.2207e-03, -5.9814e-03,  ...,  2.5024e-03,
#          -2.7008e-03,  6.3782e-03],
#         ...,
#         [ 1.1139e-03,  2.2583e-03, -1.8692e-03,  ...,  1.6632e-03,
#           5.6458e-03, -5.8289e-03],
#         [ 5.4169e-04,  2.0885e-04, -2.5482e-03,  ..., -5.7983e-03,
#          -3.2196e-03,  9.2030e-05],
#         [-1.1396e-04, -2.1973e-03, -1.7357e-04,  ..., -2.4986e-04,
#           4.6539e-04,  2.3956e-03]], dtype=torch.bfloat16))
# ('model.layers.16.mlp.up_proj.weight', tensor([[ 1.3428e-03, -4.6692e-03, -2.4414e-03,  ..., -2.5482e-03,
#          -1.0605e-03, -4.2114e-03],
#         [-3.3760e-04,  4.0588e-03, -1.1778e-04,  ...,  2.7313e-03,
#          -2.7161e-03,  9.4986e-04],
#         [-2.4414e-03,  1.2360e-03, -6.7520e-04,  ..., -2.0752e-03,
#          -5.8594e-03,  2.5482e-03],
#         ...,
#         [-2.8229e-03, -1.5945e-03, -2.4261e-03,  ..., -1.8005e-03,
#          -2.1667e-03, -2.8534e-03],
#         [-3.6163e-03,  2.8534e-03, -1.2817e-03,  ...,  6.2943e-04,
#           4.5166e-03, -5.0659e-03],
#         [-9.0332e-03, -1.2589e-03,  3.5706e-03,  ...,  1.4420e-03,
#          -1.7395e-03,  6.1512e-05]], dtype=torch.bfloat16))
# ('model.layers.16.post_attention_layernorm.weight', tensor([2.1406, 4.5000, 2.5156,  ..., 1.9844, 2.1250, 2.1719],
#        dtype=torch.bfloat16))
# ('model.layers.16.self_attn.k_proj.weight', tensor([[ 3.1710e-05,  2.7618e-03,  2.7924e-03,  ...,  3.0060e-03,
#           8.2779e-04, -2.0905e-03],
#         [-2.3346e-03, -1.8716e-05, -7.4005e-04,  ..., -3.6163e-03,
#           1.4343e-03,  1.8921e-03],
#         [ 1.1292e-03,  9.6130e-04,  3.0823e-03,  ...,  8.5449e-04,
#           3.1738e-03, -1.4648e-03],
#         ...,
#         [ 1.7738e-04, -7.0190e-04, -1.0834e-03,  ..., -4.8447e-04,
#          -1.6785e-03,  7.7820e-04],
#         [-1.4725e-03,  2.1820e-03, -1.4420e-03,  ...,  3.1586e-03,
#          -3.8910e-03, -2.9144e-03],
#         [ 1.0223e-03,  7.3547e-03, -5.7983e-03,  ..., -1.1658e-02,
#           2.7618e-03, -6.3782e-03]], dtype=torch.bfloat16))
# ('model.layers.16.self_attn.o_proj.weight', tensor([[ 2.4567e-03, -1.8997e-03,  2.9907e-03,  ...,  2.2430e-03,
#          -3.1281e-03,  3.4027e-03],
#         [ 1.0605e-03,  1.4267e-03,  2.9602e-03,  ..., -2.0905e-03,
#          -3.9482e-04, -1.2817e-03],
#         [-5.5847e-03, -7.8201e-04, -6.5613e-04,  ...,  1.4973e-04,
#          -4.7493e-04,  4.3869e-05],
#         ...,
#         [-3.4027e-03, -2.1553e-04, -3.8528e-04,  ..., -2.5940e-03,
#           1.1597e-03,  3.3569e-03],
#         [ 1.5869e-03, -2.4796e-04, -3.0823e-03,  ...,  6.9046e-04,
#           3.4485e-03,  3.0975e-03],
#         [-3.0365e-03, -1.7929e-03, -3.5858e-03,  ..., -3.2196e-03,
#          -5.7983e-04,  3.2349e-03]], dtype=torch.bfloat16))
# ('model.layers.16.self_attn.q_proj.weight', tensor([[-2.2430e-03,  4.4556e-03, -9.4891e-05,  ...,  2.8229e-03,
#           1.6403e-03, -6.2943e-04],
#         [ 6.3324e-04, -3.2501e-03, -2.9449e-03,  ...,  2.3346e-03,
#           2.0905e-03, -1.5411e-03],
#         [ 5.5313e-04,  3.6469e-03,  5.7983e-04,  ...,  2.5558e-04,
#          -1.6403e-03,  5.9509e-04],
#         ...,
#         [ 2.6855e-03, -2.0123e-04,  2.7084e-04,  ..., -4.5471e-03,
#           5.1270e-03, -1.8883e-04],
#         [-1.3962e-03,  1.4648e-03,  1.4496e-03,  ...,  2.4438e-05,
#           4.1199e-03,  3.9673e-03],
#         [ 1.9226e-03,  6.4850e-04, -2.3804e-03,  ..., -1.7319e-03,
#          -3.0823e-03, -6.5308e-03]], dtype=torch.bfloat16))
# ('model.layers.16.self_attn.v_proj.weight', tensor([[ 6.1035e-04,  1.2696e-05, -4.2114e-03,  ..., -3.2806e-03,
#           1.0452e-03, -9.0790e-04],
#         [ 1.9360e-04, -5.7459e-05,  1.1520e-03,  ..., -2.9602e-03,
#          -2.8076e-03,  1.1978e-03],
#         [ 3.0518e-03, -1.9989e-03, -1.3428e-03,  ..., -2.6093e-03,
#          -2.5330e-03, -1.8997e-03],
#         ...,
#         [ 1.3199e-03, -6.2561e-04, -2.2430e-03,  ...,  1.5030e-03,
#           1.1520e-03, -4.5776e-03],
#         [ 2.8419e-04,  1.1520e-03, -7.3624e-04,  ..., -2.9297e-03,
#           2.5558e-04,  3.4790e-03],
#         [-2.2736e-03,  1.6556e-03,  7.8583e-04,  ..., -1.9836e-03,
#           5.4626e-03,  2.6245e-03]], dtype=torch.bfloat16))
# ('model.layers.17.input_layernorm.weight', tensor([2.0781, 3.5312, 2.3906,  ..., 1.8125, 1.9219, 2.1406],
#        dtype=torch.bfloat16))
# ('model.layers.17.mlp.down_proj.weight', tensor([[ 0.0029, -0.0025,  0.0020,  ...,  0.0018, -0.0032, -0.0037],
#         [ 0.0030, -0.0014,  0.0079,  ...,  0.0010, -0.0025,  0.0011],
#         [ 0.0004, -0.0016, -0.0014,  ..., -0.0002,  0.0052, -0.0013],
#         ...,
#         [-0.0012, -0.0014, -0.0015,  ..., -0.0046, -0.0057, -0.0017],
#         [-0.0008, -0.0021, -0.0009,  ..., -0.0004,  0.0018, -0.0006],
#         [-0.0029,  0.0044, -0.0026,  ...,  0.0014, -0.0023,  0.0029]],
#        dtype=torch.bfloat16))
# ('model.layers.17.mlp.gate_proj.weight', tensor([[ 4.6387e-03,  4.2114e-03,  2.2697e-04,  ...,  2.8992e-03,
#          -2.7313e-03,  3.7689e-03],
#         [-1.2436e-03,  2.2125e-04,  7.2479e-04,  ..., -1.1063e-03,
#          -3.2043e-03,  2.3346e-03],
#         [-3.1891e-03, -2.5635e-03,  1.5106e-03,  ...,  3.5706e-03,
#           1.0681e-03, -1.9455e-03],
#         ...,
#         [ 3.5667e-04,  5.3406e-04,  2.3460e-04,  ..., -1.2207e-03,
#           1.1292e-03,  7.6675e-04],
#         [ 4.6387e-03,  3.7079e-03, -2.4872e-03,  ...,  9.1553e-03,
#          -4.0894e-03, -3.4332e-03],
#         [-5.1880e-03,  1.2817e-03,  1.8234e-03,  ..., -3.3875e-03,
#          -6.9809e-04, -4.9829e-05]], dtype=torch.bfloat16))
# ('model.layers.17.mlp.up_proj.weight', tensor([[-1.7090e-03,  2.7313e-03,  2.2888e-03,  ..., -4.3869e-04,
#           5.2490e-03, -4.3640e-03],
#         [ 3.3112e-03,  7.8125e-03, -4.8523e-03,  ...,  2.4414e-03,
#           5.8594e-03, -3.6621e-03],
#         [-1.1749e-03, -2.5482e-03,  3.9673e-03,  ...,  2.4414e-03,
#           1.0729e-04,  7.3242e-04],
#         ...,
#         [ 1.1292e-03, -9.9182e-04, -7.2327e-03,  ...,  2.0447e-03,
#          -1.9989e-03,  4.8828e-04],
#         [-2.6703e-03,  1.5182e-03,  4.5471e-03,  ..., -3.2501e-03,
#          -4.5967e-04, -3.7231e-03],
#         [-1.2207e-03,  1.8387e-03, -7.7248e-05,  ..., -6.3782e-03,
#          -5.3711e-03, -1.1063e-03]], dtype=torch.bfloat16))
# ('model.layers.17.post_attention_layernorm.weight', tensor([2.3125, 4.4375, 2.6719,  ..., 2.1562, 2.3125, 2.3281],
#        dtype=torch.bfloat16))
# ('model.layers.17.self_attn.k_proj.weight', tensor([[ 1.4954e-03,  4.3030e-03, -4.8523e-03,  ..., -3.3875e-03,
#           2.4109e-03,  3.1471e-04],
#         [ 6.8665e-04,  4.2419e-03,  2.7771e-03,  ..., -5.3406e-03,
#           1.3504e-03, -3.3875e-03],
#         [ 2.5177e-03, -5.6763e-03,  5.7936e-05,  ..., -2.3041e-03,
#           8.3160e-04, -1.5182e-03],
#         ...,
#         [ 5.7983e-03, -9.3384e-03,  2.5177e-03,  ..., -1.3924e-04,
#          -2.6703e-03,  6.7444e-03],
#         [-4.6692e-03, -1.9989e-03,  6.9580e-03,  ...,  9.8267e-03,
#          -6.3477e-03,  2.4567e-03],
#         [ 4.6692e-03,  8.4839e-03, -7.3242e-04,  ..., -1.3885e-03,
#           6.4087e-04, -8.3008e-03]], dtype=torch.bfloat16))
# ('model.layers.17.self_attn.o_proj.weight', tensor([[-0.0004, -0.0014, -0.0031,  ...,  0.0042,  0.0012,  0.0023],
#         [ 0.0013, -0.0014,  0.0004,  ..., -0.0015, -0.0026, -0.0020],
#         [ 0.0012, -0.0014,  0.0021,  ..., -0.0027,  0.0044,  0.0044],
#         ...,
#         [-0.0023, -0.0044, -0.0014,  ...,  0.0062,  0.0031, -0.0031],
#         [ 0.0025,  0.0006, -0.0043,  ...,  0.0021,  0.0003, -0.0035],
#         [ 0.0040,  0.0030, -0.0027,  ..., -0.0037, -0.0029, -0.0050]],
#        dtype=torch.bfloat16))
# ('model.layers.17.self_attn.q_proj.weight', tensor([[-2.7466e-03, -8.6670e-03,  3.4332e-03,  ..., -2.1362e-03,
#          -5.3101e-03, -1.7319e-03],
# ...
#         [ 0.0004,  0.0005, -0.0040,  ..., -0.0060, -0.0013, -0.0022],
#         [-0.0010,  0.0076,  0.0006,  ..., -0.0010, -0.0009, -0.0022]],
#        dtype=torch.bfloat16))
# ('model.layers.6.self_attn.q_proj.weight', tensor([[-8.0490e-04,  9.2773e-03,  2.8849e-05,  ..., -6.0120e-03,
#          -3.8300e-03, -4.4556e-03],
#         [-4.2725e-03,  2.4719e-03,  5.8899e-03,  ...,  1.4191e-03,
#          -7.8201e-04,  1.4343e-03],
#         [ 3.0975e-03, -8.6060e-03, -4.2114e-03,  ...,  2.1973e-03,
#           1.7929e-03,  2.8076e-03],
#         ...,
#         [ 3.4332e-03, -2.4033e-04,  1.2131e-03,  ...,  3.7079e-03,
#          -1.1749e-03,  2.3193e-03],
#         [-5.8746e-04, -3.2501e-03,  2.6093e-03,  ...,  6.6223e-03,
#          -1.5869e-03, -4.5471e-03],
#         [ 3.8910e-03,  1.8692e-03, -6.3171e-03,  ..., -9.3384e-03,
#           5.3711e-03,  6.7749e-03]], dtype=torch.bfloat16))
# ('model.layers.6.self_attn.v_proj.weight', tensor([[ 1.1978e-03, -3.9062e-03,  1.0376e-03,  ...,  6.9046e-04,
#           5.0049e-03, -1.1444e-03],
#         [ 4.7112e-04, -6.4087e-04, -1.4114e-03,  ...,  2.0905e-03,
#          -4.1962e-05, -2.6855e-03],
#         [-1.4954e-03,  1.1826e-03, -1.6327e-03,  ...,  9.4986e-04,
#           3.3722e-03,  9.0408e-04],
#         ...,
#         [ 1.2665e-03,  4.8828e-04,  5.3406e-03,  ...,  2.1515e-03,
#          -4.6692e-03,  4.0436e-04],
#         [-3.4637e-03,  5.5542e-03, -2.3041e-03,  ...,  8.5354e-05,
#          -3.0212e-03, -6.6376e-04],
#         [ 1.7014e-03, -4.1199e-03, -7.8964e-04,  ...,  1.6403e-03,
#          -3.6011e-03, -2.1667e-03]], dtype=torch.bfloat16))
# ('model.layers.7.input_layernorm.weight', tensor([1.3438, 1.2188, 1.2891,  ..., 1.2812, 1.3359, 1.2188],
#        dtype=torch.bfloat16))
# ('model.layers.7.mlp.down_proj.weight', tensor([[-9.0027e-04,  3.6316e-03, -2.6093e-03,  ...,  5.7373e-03,
#          -1.1597e-03,  4.4250e-03],
#         [-1.3123e-03, -6.1646e-03, -2.1973e-03,  ...,  2.2888e-03,
#           3.3855e-05, -2.6584e-05],
#         [ 7.5150e-04,  1.8921e-03,  1.0300e-03,  ...,  6.4087e-03,
#           2.3346e-03, -1.8234e-03],
#         ...,
#         [ 5.7373e-03, -2.0447e-03, -2.6093e-03,  ...,  1.6251e-03,
#          -1.2054e-03, -7.0953e-04],
#         [ 4.4250e-03, -4.9210e-04, -5.7220e-04,  ..., -3.3569e-03,
#          -9.6893e-04, -3.2501e-03],
#         [-3.9978e-03,  8.3618e-03, -1.8234e-03,  ..., -6.4697e-03,
#          -3.9864e-04, -1.5335e-03]], dtype=torch.bfloat16))
# ('model.layers.7.mlp.gate_proj.weight', tensor([[-2.0142e-03, -4.1504e-03, -7.7209e-03,  ...,  1.1597e-03,
#           4.7922e-05, -3.7384e-04],
#         [-7.8583e-04, -5.0659e-03,  6.4850e-04,  ..., -3.4790e-03,
#          -4.0894e-03,  3.0708e-04],
#         [ 4.3335e-03,  3.9368e-03, -1.0925e-02,  ...,  1.5640e-03,
#           2.3937e-04,  2.7466e-03],
#         ...,
#         [ 4.6692e-03, -5.1270e-03,  3.4027e-03,  ...,  3.2043e-03,
#           1.2360e-03,  2.4872e-03],
#         [ 2.9449e-03, -3.8605e-03,  1.5106e-03,  ...,  5.4016e-03,
#          -2.4872e-03, -2.2583e-03],
#         [ 1.3580e-03, -2.7771e-03, -1.4648e-03,  ..., -8.0490e-04,
#          -6.8359e-03, -8.3447e-05]], dtype=torch.bfloat16))
# ('model.layers.7.mlp.up_proj.weight', tensor([[-2.1057e-03,  3.7575e-04,  5.2643e-04,  ...,  4.0283e-03,
#          -1.7395e-03, -1.1673e-03],
#         [ 4.6692e-03,  2.6703e-03,  3.9062e-03,  ..., -1.5488e-03,
#           1.3447e-04, -1.6556e-03],
#         [-3.6469e-03,  7.2937e-03, -9.0790e-04,  ...,  2.0294e-03,
#           2.0905e-03,  1.7166e-03],
#         ...,
#         [ 5.7068e-03,  6.7139e-04,  4.6997e-03,  ...,  1.9908e-05,
#          -6.1951e-03, -1.6098e-03],
#         [-4.8523e-03,  3.2501e-03, -5.5313e-04,  ..., -4.0283e-03,
#          -6.4087e-04, -7.7438e-04],
#         [ 2.2278e-03,  1.2436e-03, -1.4267e-03,  ...,  2.1458e-04,
#           4.3335e-03,  6.2561e-04]], dtype=torch.bfloat16))
# ('model.layers.7.post_attention_layernorm.weight', tensor([1.3672, 1.5234, 1.4922,  ..., 1.3594, 1.3906, 1.3984],
#        dtype=torch.bfloat16))
# ('model.layers.7.self_attn.k_proj.weight', tensor([[-1.3199e-03, -4.5013e-04,  3.1128e-03,  ..., -2.3193e-03,
#          -3.9368e-03, -2.4261e-03],
#         [ 3.0670e-03,  1.2360e-03, -2.8687e-03,  ..., -1.6403e-03,
#           3.0518e-03,  2.6703e-03],
#         [ 1.2360e-03, -2.9755e-03, -2.7008e-03,  ...,  4.4060e-04,
#           2.4109e-03, -7.8201e-05],
#         ...,
#         [-5.4016e-03, -5.3101e-03, -2.6398e-03,  ..., -2.8687e-03,
#           5.9814e-03, -8.3008e-03],
#         [ 1.1353e-02,  8.2397e-04, -6.3477e-03,  ..., -9.2163e-03,
#          -5.3101e-03,  7.5073e-03],
#         [-1.0803e-02,  3.1090e-04,  9.1553e-03,  ...,  1.3062e-02,
#           1.1108e-02,  1.1169e-02]], dtype=torch.bfloat16))
# ('model.layers.7.self_attn.o_proj.weight', tensor([[-1.0910e-03,  4.5776e-04, -3.2806e-04,  ..., -4.0531e-05,
#           4.3030e-03, -1.8311e-03],
#         [ 5.2795e-03,  2.6345e-05,  1.3065e-04,  ..., -2.8992e-03,
#           1.4343e-03,  2.1973e-03],
#         [ 1.0681e-03,  1.6556e-03,  2.0599e-03,  ..., -3.5706e-03,
#           1.5869e-03, -6.2943e-04],
#         ...,
#         [-2.1057e-03,  1.3123e-03,  5.3167e-05,  ...,  1.2283e-03,
#          -3.1281e-03, -7.7057e-04],
#         [-1.7319e-03, -6.1035e-03,  7.0190e-04,  ...,  3.7689e-03,
#          -5.2185e-03, -7.2479e-04],
#         [-1.0223e-03,  6.5994e-04, -2.8381e-03,  ...,  1.7471e-03,
#          -1.6708e-03, -1.9908e-05]], dtype=torch.bfloat16))
# ('model.layers.7.self_attn.q_proj.weight', tensor([[-1.7395e-03,  1.9646e-04, -6.3419e-05,  ...,  9.1934e-04,
#          -2.4261e-03,  1.3504e-03],
#         [-3.1891e-03, -4.2419e-03,  3.4485e-03,  ..., -2.1210e-03,
#           2.8381e-03, -5.4932e-03],
#         [ 2.2583e-03,  3.3722e-03,  2.4414e-03,  ...,  1.1597e-03,
#           2.0142e-03, -2.8992e-03],
#         ...,
#         [ 1.0986e-02, -6.4392e-03,  3.7537e-03,  ...,  1.4801e-03,
#           5.8746e-04, -7.6294e-03],
#         [-1.2939e-02,  6.1417e-04,  5.7983e-03,  ..., -3.3875e-03,
#          -6.4087e-03, -2.9449e-03],
#         [ 2.7313e-03, -1.1719e-02, -1.8997e-03,  ..., -1.5335e-03,
#           1.1658e-02, -5.4932e-03]], dtype=torch.bfloat16))
# ('model.layers.7.self_attn.v_proj.weight', tensor([[-2.4719e-03,  2.7466e-03, -1.7834e-04,  ..., -9.2316e-04,
#          -9.8419e-04, -1.6327e-03],
#         [ 1.2207e-03,  5.4932e-04,  1.5831e-04,  ..., -4.3297e-04,
#          -9.2697e-04,  5.8365e-04],
#         [ 1.4973e-04, -4.3631e-05,  1.5030e-03,  ...,  5.0735e-04,
#          -1.7700e-03, -1.2970e-03],
#         ...,
#         [-3.1090e-04, -8.1177e-03,  1.1292e-03,  ...,  4.0283e-03,
#           4.4861e-03,  1.5411e-03],
#         [ 2.1820e-03,  5.6152e-03, -7.7438e-04,  ...,  2.7418e-05,
#          -2.0599e-04, -3.8300e-03],
#         [ 4.6387e-03, -1.3809e-03, -9.3460e-04,  ...,  1.1520e-03,
#           2.4872e-03,  1.5488e-03]], dtype=torch.bfloat16))
# ('model.layers.8.input_layernorm.weight', tensor([1.3438, 1.2969, 1.4609,  ..., 1.2188, 1.4297, 1.2422],
#        dtype=torch.bfloat16))
# ('model.layers.8.mlp.down_proj.weight', tensor([[-0.0014, -0.0009, -0.0023,  ..., -0.0037, -0.0022, -0.0021],
#         [-0.0040, -0.0008, -0.0033,  ...,  0.0030, -0.0002,  0.0043],
#         [ 0.0053,  0.0017,  0.0017,  ...,  0.0033, -0.0042, -0.0070],
#         ...,
#         [-0.0022,  0.0056, -0.0009,  ...,  0.0049, -0.0012, -0.0027],
#         [-0.0016,  0.0045,  0.0019,  ..., -0.0013, -0.0018, -0.0019],
#         [-0.0037, -0.0009,  0.0022,  ..., -0.0015, -0.0016,  0.0061]],
#        dtype=torch.bfloat16))
# ('model.layers.8.mlp.gate_proj.weight', tensor([[-0.0006,  0.0030,  0.0017,  ...,  0.0061,  0.0021, -0.0020],
#         [ 0.0047, -0.0021,  0.0010,  ..., -0.0060, -0.0022, -0.0029],
#         [-0.0040, -0.0010,  0.0023,  ..., -0.0039,  0.0012, -0.0032],
#         ...,
#         [-0.0033,  0.0020, -0.0040,  ..., -0.0028, -0.0002, -0.0020],
#         [-0.0004, -0.0015, -0.0030,  ...,  0.0012, -0.0002,  0.0052],
#         [ 0.0030, -0.0017,  0.0012,  ..., -0.0026, -0.0045, -0.0071]],
#        dtype=torch.bfloat16))
# ('model.layers.8.mlp.up_proj.weight', tensor([[ 0.0024, -0.0005,  0.0031,  ..., -0.0013,  0.0016, -0.0017],
#         [ 0.0008, -0.0049,  0.0014,  ...,  0.0036, -0.0026, -0.0021],
#         [-0.0056, -0.0015,  0.0002,  ...,  0.0014,  0.0022,  0.0008],
#         ...,
#         [-0.0048,  0.0028,  0.0045,  ...,  0.0049,  0.0048, -0.0003],
#         [-0.0045,  0.0021,  0.0016,  ..., -0.0007, -0.0030,  0.0025],
#         [-0.0006,  0.0029, -0.0020,  ..., -0.0026, -0.0010,  0.0085]],
#        dtype=torch.bfloat16))
# ('model.layers.8.post_attention_layernorm.weight', tensor([1.4062, 1.6328, 1.6250,  ..., 1.3906, 1.4609, 1.5000],
#        dtype=torch.bfloat16))
# ('model.layers.8.self_attn.k_proj.weight', tensor([[ 0.0011,  0.0005, -0.0009,  ..., -0.0037,  0.0029,  0.0015],
#         [-0.0002,  0.0015, -0.0024,  ...,  0.0002, -0.0044, -0.0025],
#         [-0.0014, -0.0002,  0.0021,  ..., -0.0016,  0.0034,  0.0035],
#         ...,
#         [ 0.0047,  0.0022, -0.0030,  ...,  0.0025, -0.0009,  0.0004],
#         [-0.0010,  0.0065,  0.0033,  ...,  0.0018, -0.0028, -0.0058],
#         [-0.0010, -0.0023,  0.0037,  ...,  0.0029,  0.0016,  0.0040]],
#        dtype=torch.bfloat16))
# ('model.layers.8.self_attn.o_proj.weight', tensor([[-7.6294e-04, -9.6130e-04, -3.0060e-03,  ...,  2.9602e-03,
#          -3.3188e-04,  1.6556e-03],
#         [-4.5166e-03,  4.5967e-04,  8.5449e-04,  ..., -1.2436e-03,
#          -2.2430e-03,  7.2861e-04],
#         [-2.9297e-03,  2.9564e-04, -1.8616e-03,  ..., -1.5793e-03,
#           7.7057e-04,  2.1667e-03],
#         ...,
#         [-4.8447e-04,  6.2561e-04,  8.5068e-04,  ...,  1.8539e-03,
#          -1.8835e-05,  2.0294e-03],
#         [-2.8534e-03, -8.8882e-04,  2.4567e-03,  ..., -2.4109e-03,
#           3.2043e-04, -5.7373e-03],
#         [ 3.4523e-04, -1.8845e-03,  1.1139e-03,  ...,  1.2283e-03,
#          -1.8234e-03,  2.0905e-03]], dtype=torch.bfloat16))
# ('model.layers.8.self_attn.q_proj.weight', tensor([[ 2.4872e-03, -2.2736e-03, -3.9673e-03,  ...,  2.2888e-04,
#          -3.0823e-03, -5.9891e-04],
#         [ 6.1798e-04,  1.4420e-03,  1.2207e-03,  ...,  3.4180e-03,
#           5.4550e-04,  2.6398e-03],
#         [ 8.0109e-04, -1.6327e-03, -6.0654e-04,  ..., -1.9836e-03,
#          -2.1820e-03, -2.7466e-03],
#         ...,
#         [-1.7395e-03,  2.5940e-03, -1.3199e-03,  ...,  1.3733e-03,
#           6.0272e-04,  4.8828e-03],
#         [ 5.4321e-03,  2.1973e-03,  4.1008e-05,  ..., -4.9133e-03,
#          -1.7090e-03, -6.3477e-03],
#         [ 1.5259e-05,  1.7395e-03,  3.6316e-03,  ...,  4.0283e-03,
#          -2.3193e-03,  7.9727e-04]], dtype=torch.bfloat16))
# ('model.layers.8.self_attn.v_proj.weight', tensor([[-3.2959e-03,  2.0599e-03,  7.2098e-04,  ..., -2.7924e-03,
#          -2.3460e-04, -3.9978e-03],
#         [ 3.0708e-04, -1.9379e-03, -2.2888e-03,  ..., -3.2501e-03,
#          -1.8311e-03,  1.8082e-03],
#         [-3.0670e-03, -2.8229e-04,  1.1921e-04,  ..., -3.6621e-04,
#          -9.1553e-04, -4.1199e-04],
#         ...,
#         [ 1.3657e-03, -1.2970e-03, -5.2643e-04,  ...,  4.8065e-04,
#           1.1520e-03, -3.0212e-03],
#         [ 1.2436e-03,  2.1553e-04, -1.5259e-04,  ...,  1.0300e-03,
#          -1.4343e-03,  2.7618e-03],
#         [-2.3804e-03,  5.0964e-03,  1.8005e-03,  ..., -2.3346e-03,
#           4.2677e-05, -2.4719e-03]], dtype=torch.bfloat16))
# ('model.layers.9.input_layernorm.weight', tensor([1.6250, 1.6797, 1.8281,  ..., 1.4141, 1.7188, 1.6250],
#        dtype=torch.bfloat16))
# ('model.layers.9.mlp.down_proj.weight', tensor([[ 4.1199e-03, -1.3351e-03,  1.4572e-03,  ..., -4.2114e-03,
#           1.9073e-03,  7.5684e-03],
#         [-1.1597e-03, -5.8594e-03, -4.3106e-04,  ..., -8.3008e-03,
#           7.6294e-04,  1.6632e-03],
#         [-4.6692e-03, -3.7231e-03, -2.9602e-03,  ...,  4.6997e-03,
#          -1.6098e-03,  3.7689e-03],
#         ...,
#         [-3.7193e-04, -1.3199e-03,  4.3945e-03,  ...,  1.9150e-03,
#           5.5542e-03,  3.0708e-04],
#         [ 2.4261e-03, -1.4210e-04, -2.9297e-03,  ...,  5.3883e-05,
#          -2.3651e-03, -4.1809e-03],
#         [-2.6093e-03, -6.5231e-04, -4.0894e-03,  ..., -2.6550e-03,
#           2.8419e-04,  3.2806e-04]], dtype=torch.bfloat16))
# ('model.layers.9.mlp.gate_proj.weight', tensor([[-2.2278e-03, -1.3828e-04,  3.5858e-03,  ...,  1.6403e-03,
#           1.0395e-04,  2.9182e-04],
#         [-2.3041e-03,  7.6294e-04, -1.1215e-03,  ...,  4.8523e-03,
#          -7.8678e-05, -2.1667e-03],
#         [-8.8882e-04,  3.2196e-03,  2.0142e-03,  ..., -2.5024e-03,
#          -8.9722e-03,  1.5869e-03],
#         ...,
#         [ 8.1787e-03,  1.0254e-02, -9.8419e-04,  ..., -1.4877e-03,
#           3.1128e-03, -4.6082e-03],
#         [ 2.9449e-03, -9.8419e-04, -2.0752e-03,  ..., -3.6011e-03,
#           2.9144e-03,  2.0752e-03],
#         [-6.5231e-04,  4.0588e-03, -3.3112e-03,  ...,  2.2583e-03,
#          -1.2283e-03,  5.7373e-03]], dtype=torch.bfloat16))
# ('model.layers.9.mlp.up_proj.weight', tensor([[-1.1597e-03, -1.6708e-03,  9.3842e-04,  ...,  2.6550e-03,
#           5.0735e-04,  2.4567e-03],
#         [-5.7068e-03, -5.3406e-03, -1.2207e-03,  ...,  4.7607e-03,
#           9.1076e-05,  2.1667e-03],
#         [ 2.1057e-03,  1.0014e-04, -4.0894e-03,  ...,  1.4572e-03,
#          -1.7452e-04, -1.4420e-03],
#         ...,
#         [-1.2589e-04, -1.2268e-02, -1.2512e-03,  ..., -4.6692e-03,
#          -3.7231e-03, -3.5553e-03],
#         [-1.3199e-03,  5.9128e-04,  2.2793e-04,  ...,  3.0136e-04,
#          -2.7084e-04,  1.6251e-03],
#         [ 3.2654e-03, -8.7738e-04, -2.9755e-03,  ..., -2.8839e-03,
#          -4.4250e-03, -3.8605e-03]], dtype=torch.bfloat16))
# ('model.layers.9.post_attention_layernorm.weight', tensor([1.4375, 1.7500, 1.7188,  ..., 1.3672, 1.4609, 1.5312],
#        dtype=torch.bfloat16))
# ('model.layers.9.self_attn.k_proj.weight', tensor([[ 0.0009,  0.0008,  0.0009,  ...,  0.0025, -0.0022,  0.0039],
#         [-0.0033,  0.0005, -0.0013,  ..., -0.0005,  0.0059,  0.0002],
#         [ 0.0009,  0.0009,  0.0018,  ...,  0.0002, -0.0003,  0.0017],
#         ...,
#         [-0.0056,  0.0053, -0.0024,  ...,  0.0065,  0.0003, -0.0063],
#         [-0.0023,  0.0098,  0.0025,  ...,  0.0098,  0.0003, -0.0038],
#         [-0.0031, -0.0087,  0.0039,  ...,  0.0038, -0.0146,  0.0022]],
#        dtype=torch.bfloat16))
# ('model.layers.9.self_attn.o_proj.weight', tensor([[-0.0054,  0.0003,  0.0031,  ...,  0.0008,  0.0018, -0.0001],
#         [-0.0026, -0.0007,  0.0029,  ...,  0.0013,  0.0013,  0.0026],
#         [ 0.0047,  0.0015,  0.0027,  ...,  0.0043, -0.0003,  0.0014],
#         ...,
#         [-0.0034, -0.0023, -0.0002,  ...,  0.0047, -0.0013,  0.0005],
#         [-0.0025,  0.0007, -0.0014,  ...,  0.0018,  0.0015, -0.0044],
#         [-0.0002, -0.0035,  0.0026,  ..., -0.0015, -0.0023, -0.0015]],
#        dtype=torch.bfloat16))
# ('model.layers.9.self_attn.q_proj.weight', tensor([[ 9.1171e-04,  2.6093e-03, -3.7003e-04,  ..., -3.3112e-03,
#          -6.3477e-03, -7.3547e-03],
#         [-5.5313e-04, -2.7008e-03,  3.0060e-03,  ..., -3.8300e-03,
#           3.7384e-03, -4.2419e-03],
#         [-9.1553e-04,  5.6458e-03, -3.5477e-04,  ..., -1.7166e-03,
#          -3.7842e-03,  5.8365e-04],
#         ...,
#         [-1.6327e-03, -7.5684e-03, -5.0049e-03,  ...,  6.5804e-05,
#           8.7280e-03, -7.9956e-03],
#         [ 4.6387e-03,  1.6357e-02, -3.6316e-03,  ...,  5.0049e-03,
#           2.7466e-03, -3.3569e-03],
#         [ 5.5542e-03, -3.0060e-03, -3.0670e-03,  ...,  1.2817e-03,
#          -9.2773e-03,  7.2479e-04]], dtype=torch.bfloat16))
# ('model.layers.9.self_attn.v_proj.weight', tensor([[-5.0354e-03, -1.4343e-03,  2.1362e-03,  ..., -1.9455e-03,
#          -2.4719e-03,  1.2360e-03],
#         [-1.0147e-03, -2.2507e-04, -3.1281e-03,  ..., -2.0599e-03,
#           1.8845e-03, -1.4038e-03],
#         [ 2.5787e-03,  2.6703e-03, -2.0142e-03,  ...,  1.4877e-03,
#          -1.0681e-03,  1.1368e-03],
#         ...,
#         [-1.1139e-03, -4.1962e-04,  2.2430e-03,  ...,  4.7684e-05,
#           9.4414e-05, -2.8076e-03],
#         [ 1.5793e-03, -2.6398e-03,  1.2131e-03,  ...,  4.7302e-04,
#          -1.9379e-03,  1.7700e-03],
#         [-3.1891e-03,  3.2196e-03,  3.3760e-04,  ...,  2.5368e-04,
#           2.9945e-04,  2.2793e-04]], dtype=torch.bfloat16))
# ('model.norm.weight', tensor([5.3438, 5.5312, 5.4062,  ..., 5.2812, 5.5625, 5.2812],
#        dtype=torch.bfloat16))

# %%
model_loader_test.get_tensor("model.layers.0.self_attn.k_proj.weight")

# %%
import torch
file_path = 'pytorch_model.bin'
state_dict = torch.load(file_path, map_location='cpu')
